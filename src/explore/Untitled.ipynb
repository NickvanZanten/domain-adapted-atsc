# %%
import pandas as pd
import matplotlib as plt
import numpy as np

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 12, 7

# %%
df = pd.read_json('../../data/raw/bain.nosync/annotations_gold_revised_v2.jsonl', lines=True)

# %%
df.shape
# Out:
# (3313, 12)

# %%
df.head()
# Out:
#                                                 text  \
# 0              45 years of great service and support
# 1              45 years of great service and support
# 2              45 years of great service and support
# 3                            A good level of service
# 4  A number of reasons of scored Suncorp 9 out of...
#
#                           category sentiment    0 Country  NPS options  \
# 0                    brand#loyalty  positive  3.0     NaN  NaN     NaN
# 1  customer_service#advice_support  positive  2.0     NaN  NaN     NaN
# 2         customer_service#quality  positive  3.0     NaN  NaN     NaN
# 3         customer_service#quality  positive  3.0     NaN  NaN     NaN
# 4            brand#brand_mentioned  positive  2.0     NaN  NaN     NaN
#
#    _input_hash  _task_hash  _session_id _view_id answer
# 0          NaN         NaN          NaN      NaN    NaN
# 1          NaN         NaN          NaN      NaN    NaN
# ...

# %%
df['category'].value_counts().plot(kind='bar')

# %%
import xml.etree.ElementTree as ET
import pandas as pd

# %%
sentimap = {
        'positive': 'POS',
        'negative': 'NEG',
        'neutral': 'NEU',
        'conflict': 'CONF',
    }


with open('../../data/transformed/semeval2016_acsc_laptops_noconfl/train.xml') as file:

        review_elements = ET.parse(file).getroot().iter('sentence')
        
        sentences = []
        aspect_category_sentiments = []
        classes = set([])

        for j, s in enumerate(review_elements):
            #review_text = ' '.join([el.find('text').text for el in s.iter('sentence')])
            
            aspect_category_sentiment = []
            for o in s.iter('aspectTerms'):
                aspect_category = o.get('term')
                classes.add(aspect_category)
                sentiment = sentimap[o.get('polarity')]
                if sentiment != 'CONF':
                    aspect_category_sentiment.append((aspect_category, sentiment))
                else:
                    if remove_conflicting:
                        pass
                        # print('Conflicting Term found! Removed!')
                    else:
                        aspect_category_sentiment.append((aspect_category, sentiment))

            if len(aspect_category_sentiment) > 0:
                aspect_category_sentiments.append(aspect_category_sentiment)
                sentences.append(review_text)

        cats = list(classes)
        cats.sort()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-25-34456abbfe71> in <module>
#      22                 aspect_category = o.get('term')
#      23                 classes.add(aspect_category)
# ---> 24                 sentiment = sentimap[o.get('polarity')]
#      25                 if sentiment != 'CONF':
#      26                     aspect_category_sentiment.append((aspect_category, sentiment))
#
# KeyError: None

# %%
print(cats)
# Out:
# []
